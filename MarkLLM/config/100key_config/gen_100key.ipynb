# %%
import random
import string

def generate_keys(prefix, count):
    keys = set()
    while len(keys) < count:
        key = random.randint(10000000, 99999999)  # 生成8位数字
        keys.add(key)
    return list(keys)


EWD_keylist = generate_keys("EWD", 150)
PF_keylist = generate_keys("PF", 150)
SWEET_keylist = generate_keys("SWEET", 150)

print("EWD_keylist =", EWD_keylist)
print("\nPF_keylist =", PF_keylist)  
print("\nSWEET_keylist =", SWEET_keylist)

# 验证每组内部无重复
print("\n重复检查:", len(EWD_keylist) == len(set(EWD_keylist)), len(PF_keylist) == len(set(PF_keylist)), len(SWEET_keylist) == len(set(SWEET_keylist)),len(EWD_keylist),len(PF_keylist),len(SWEET_keylist))
# Out:
# EWD_keylist = [89673739, 64908299, 65870352, 65766419, 77820442, 41094173, 27175453, 17531936, 47473698, 11361314, 25786916, 19613220, 16886311, 13264424, 97125427, 38805558, 80480311, 92724793, 67954234, 55197244, 81271870, 75318337, 29437521, 44723282, 33455700, 26664023, 24011354, 39706715, 87424607, 50547808, 45892195, 35142756, 39819369, 82456682, 21846122, 40104049, 72475249, 71023731, 13690483, 11422326, 86117505, 53145218, 45142658, 55865995, 62717077, 16949398, 93489813, 20035238, 43333289, 51542186, 21422763, 86133423, 80324272, 63765681, 20331187, 67771063, 40293561, 39546562, 84667587, 38818504, 36115145, 21127889, 19549908, 25931989, 12565207, 28485338, 22738143, 24187104, 82802409, 61711601, 94871794, 49592051, 62811379, 41815806, 88950024, 89860360, 91881742, 84523282, 84929302, 82242841, 96940825, 75330849, 64328486, 80246056, 95420200, 21133610, 52556080, 29964081, 51116850, 96724277, 72330551, 40133943, 47702843, 73335613, 72227137, 97800514, 67552068, 51461962, 896
# ...

# %%
import random
import string

EWD_keylist = [89673739, 64908299, 65870352, 65766419, 77820442, 41094173, 27175453, 17531936, 47473698, 11361314, 
               25786916, 19613220, 16886311, 13264424, 97125427, 38805558, 80480311, 92724793, 67954234, 55197244, 
               81271870, 75318337, 29437521, 44723282, 33455700, 26664023, 24011354, 39706715, 87424607, 50547808, 
               45892195, 35142756, 39819369, 82456682, 21846122, 40104049, 72475249, 71023731, 13690483, 11422326, 
               86117505, 53145218, 45142658, 55865995, 62717077, 16949398, 93489813, 20035238, 43333289, 51542186, 
               21422763, 86133423, 80324272, 63765681, 20331187, 67771063, 40293561, 39546562, 84667587, 38818504, 
               36115145, 21127889, 19549908, 25931989, 12565207, 28485338, 22738143, 24187104, 82802409, 61711601, 
               94871794, 49592051, 62811379, 41815806, 88950024, 89860360, 91881742, 84523282, 84929302, 82242841, 
               96940825, 75330849, 64328486, 80246056, 95420200, 21133610, 52556080, 29964081, 51116850, 96724277, 
               72330551, 40133943, 47702843, 73335613, 72227137, 97800514, 67552068, 51461962, 89602891, 17569616, 
                 97706196, 91393752, 68802776, 44112603, 99130599, 99640559, 62200564, 24042236, 12899070, 32676096, 
                 98072837, 28993288, 67349260, 22285585, 92483352, 68892444, 62483228, 20390173, 50994976, 21010721, 
                 71686946, 10873123, 13652261, 38987049, 44541232, 51629874, 43839283, 69052211, 60057400, 16722747, 
                 60065085, 36165443, 29259590, 56393549, 86073168, 54817109, 50821977, 15851868, 81858909, 17034078, 
                 19919203, 27255653, 64237419, 60975981, 14399342, 75864431, 59531120, 87816046, 77484409, 33350014, 
                 42348927, 80733056, 88472972, 86902669, 62598544, 27339668, 71781276, 88859038, 85412256, 32786850, 
                 84518818, 69619620, 10404263, 27774375, 95176622, 35228086, 34687418, 84268990, 75872765, 13599685, 
                 49315272, 72269772, 84079053, 40968654, 26074065, 28007893, 24834010, 42653660, 84018143, 26820576, 
                 60462047, 32841700, 28640228, 86054886, 80064484, 25206761, 12942829, 91279350, 68231673, 87918589]


import json
import os
import random


templates = {
    "EWD": {
        "algorithm_name": "EWD",
        "gamma": 0.5,
        "delta": 2.0,
        "hash_key": 0,
        "prefix_length": 1,
        "z_threshold": 4.0
    },
    "SWEET": {
        "algorithm_name": "SWEET",
        "gamma": 0.5,
        "delta": 2.0,
        "hash_key": 0,
        "z_threshold": 4.0,
        "prefix_length": 1,
        "entropy_threshold": 0.9
    },
    "PF": {
        "algorithm_name": "PF",
        "ngram": 8,
        "seed": 0,
        "seeding": "hash",
        "salt_key": 0,
        "payload": 0,
        "max_seq_len": 2048
    }
}

def create_config_files(method, key_list):
    base_path = "/mnt-nfsdata/huanghanbo/MarkLLM-main/config/100key_config"
    method_path = os.path.join(base_path, f"{method}_keyconfig")
    os.makedirs(method_path, exist_ok=True)
    
    key_field = "hash_key" if method in ["EWD", "SWEET"] else "salt_key"
    
    for key in key_list:
        config = templates[method].copy()
        config[key_field] = key
        file_path = os.path.join(method_path, f"{method}_key{key}.json")
        with open(file_path, 'w') as f:
            json.dump(config, f, indent=4)
    
    print(f"✓ {method}: 已生成 {len(key_list)} 个配置文件到 {method_path}")

print("\n开始生成配置文件...")
create_config_files("EWD", EWD_keylist)
create_config_files("SWEET", SWEET_keylist)
create_config_files("PF", PF_keylist)
print("配置文件生成完成！")
# Out:
# 开始生成配置文件...
# ✓ EWD: 已生成 150 个配置文件到 /mnt-nfsdata/huanghanbo/MarkLLM-main/config/100key_config/EWD_keyconfig
# ✓ SWEET: 已生成 150 个配置文件到 /mnt-nfsdata/huanghanbo/MarkLLM-main/config/100key_config/SWEET_keyconfig
# ✓ PF: 已生成 150 个配置文件到 /mnt-nfsdata/huanghanbo/MarkLLM-main/config/100key_config/PF_keyconfig
# 配置文件生成完成！
